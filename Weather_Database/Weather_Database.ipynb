# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
#add lats and lngs to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dc = city_weather["weather"][0]["description"]
            # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | torbay
# Processing Record 4 of Set 1 | ales
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | barkly west
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | nizhniy baskunchak
# Processing Record 15 of Set 1 | upington
# Processing Record 16 of Set 1 | sayyan
# Processing Record 17 of Set 1 | tasiilaq
# Processing Record 18 of Set 1 | port blair
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | pontianak
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | charters towers
# Processing Record 26 of Set 1 | tchollire
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | changde
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | saint george
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | yamethin
# Processing Record 35 of Set 1 | severo-kurilsk
# Processing Record 36 of Set 1 | council bluffs
# Processing Record 37 of Set 1 | yendi
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | turukhansk
# Processing Record 40 of Set 1 | yeroham
# Processing Record 41 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 1 | derzhavinsk
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | constitucion
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | rocha
# Processing Record 49 of Set 1 | morant bay
# Processing Record 50 of Set 1 | bosaso
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | deputatskiy
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | saint anthony
# Processing Record 6 of Set 2 | clyde
# Processing Record 7 of Set 2 | bogande
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | khandyga
# Processing Record 10 of Set 2 | maceio
# Processing Record 11 of Set 2 | san vicente
# Processing Record 12 of Set 2 | kargil
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | abu dhabi
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | ahuimanu
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | santa isabel
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | toamasina
# Processing Record 23 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 2 | touros
# Processing Record 25 of Set 2 | japura
# Processing Record 26 of Set 2 | saint-pierre
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | axim
# Processing Record 29 of Set 2 | vostok
# Processing Record 30 of Set 2 | rikitea
# Processing Record 31 of Set 2 | kapit
# Processing Record 32 of Set 2 | eureka
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | cochabamba
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | ostrovnoy
# Processing Record 37 of Set 2 | prado
# Processing Record 38 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | mineiros
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | goundam
# Processing Record 43 of Set 2 | aland
# Processing Record 44 of Set 2 | paamiut
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | tarare
# Processing Record 47 of Set 2 | narsaq
# Processing Record 48 of Set 2 | clyde river
# Processing Record 49 of Set 2 | nelson bay
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | kysyl-syr
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | nuuk
# Processing Record 5 of Set 3 | churapcha
# Processing Record 6 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | djibo
# Processing Record 10 of Set 3 | birjand
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | igarka
# Processing Record 13 of Set 3 | aiquile
# Processing Record 14 of Set 3 | mitsamiouli
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | basoko
# Processing Record 17 of Set 3 | itaituba
# Processing Record 18 of Set 3 | vanimo
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | gravdal
# Processing Record 21 of Set 3 | kapaa
# Processing Record 22 of Set 3 | ballina
# Processing Record 23 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 24 of Set 3 | kichera
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | fukuma
# Processing Record 28 of Set 3 | santa maria
# Processing Record 29 of Set 3 | potsdam
# Processing Record 30 of Set 3 | nichinan
# Processing Record 31 of Set 3 | sao joao da barra
# Processing Record 32 of Set 3 | amurrio
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | nuoro
# Processing Record 35 of Set 3 | alihe
# Processing Record 36 of Set 3 | libertador general san martin
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | kuching
# Processing Record 39 of Set 3 | caramay
# Processing Record 40 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 3 | kahului
# Processing Record 42 of Set 3 | coahuayana
# Processing Record 43 of Set 3 | samana
# Processing Record 44 of Set 3 | serenje
# Processing Record 45 of Set 3 | shimoda
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | boo
# Processing Record 48 of Set 3 | fuerte olimpo
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | krasnozerskoye
# Processing Record 1 of Set 4 | chara
# Processing Record 2 of Set 4 | harper
# Processing Record 3 of Set 4 | hofn
# Processing Record 4 of Set 4 | ternate
# Processing Record 5 of Set 4 | asau
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | wuwei
# Processing Record 8 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | saurimo
# Processing Record 11 of Set 4 | sabang
# Processing Record 12 of Set 4 | alta floresta
# Processing Record 13 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 4 | lata
# Processing Record 15 of Set 4 | norman wells
# Processing Record 16 of Set 4 | roald
# Processing Record 17 of Set 4 | lumberton
# Processing Record 18 of Set 4 | barrow
# Processing Record 19 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 20 of Set 4 | bilibino
# Processing Record 21 of Set 4 | iquique
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | kwinana
# Processing Record 24 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 4 | sarakhs
# Processing Record 26 of Set 4 | tres picos
# Processing Record 27 of Set 4 | matamoros
# Processing Record 28 of Set 4 | bengkulu
# Processing Record 29 of Set 4 | goderich
# Processing Record 30 of Set 4 | karratha
# Processing Record 31 of Set 4 | severobaykalsk
# Processing Record 32 of Set 4 | ordzhonikidze
# Processing Record 33 of Set 4 | airai
# Processing Record 34 of Set 4 | guerrero negro
# Processing Record 35 of Set 4 | puerto ayora
# Processing Record 36 of Set 4 | am timan
# Processing Record 37 of Set 4 | saint-augustin
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | zhezkazgan
# Processing Record 40 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 41 of Set 4 | kibre mengist
# Processing Record 42 of Set 4 | cerro grande
# Processing Record 43 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | ondangwa
# Processing Record 46 of Set 4 | port lincoln
# Processing Record 47 of Set 4 | rawson
# Processing Record 48 of Set 4 | bathsheba
# Processing Record 49 of Set 4 | leningradskiy
# Processing Record 50 of Set 4 | chuy
# Processing Record 1 of Set 5 | najran
# Processing Record 2 of Set 5 | sechura
# Processing Record 3 of Set 5 | sorland
# Processing Record 4 of Set 5 | wick
# Processing Record 5 of Set 5 | cassilandia
# Processing Record 6 of Set 5 | videira
# Processing Record 7 of Set 5 | pangnirtung
# Processing Record 8 of Set 5 | kenai
# Processing Record 9 of Set 5 | mecca
# Processing Record 10 of Set 5 | librazhd
# Processing Record 11 of Set 5 | egvekinot
# Processing Record 12 of Set 5 | emerald
# Processing Record 13 of Set 5 | provideniya
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | henties bay
# Processing Record 16 of Set 5 | buchanan
# Processing Record 17 of Set 5 | tuatapere
# Processing Record 18 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 19 of Set 5 | villarrica
# Processing Record 20 of Set 5 | becerril
# Processing Record 21 of Set 5 | darnah
# Processing Record 22 of Set 5 | xichang
# Processing Record 23 of Set 5 | bahia honda
# Processing Record 24 of Set 5 | maple creek
# Processing Record 25 of Set 5 | klaksvik
# Processing Record 26 of Set 5 | yen bai
# Processing Record 27 of Set 5 | ilebo
# Processing Record 28 of Set 5 | mill valley
# Processing Record 29 of Set 5 | evensk
# Processing Record 30 of Set 5 | tezu
# Processing Record 31 of Set 5 | baran
# Processing Record 32 of Set 5 | tautira
# Processing Record 33 of Set 5 | port hardy
# Processing Record 34 of Set 5 | longyearbyen
# Processing Record 35 of Set 5 | kodiak
# Processing Record 36 of Set 5 | buala
# Processing Record 37 of Set 5 | georgetown
# Processing Record 38 of Set 5 | diego de almagro
# Processing Record 39 of Set 5 | caledon east
# Processing Record 40 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 5 | srednekolymsk
# Processing Record 42 of Set 5 | juliaca
# Processing Record 43 of Set 5 | mvuma
# Processing Record 44 of Set 5 | manali
# Processing Record 45 of Set 5 | pachperwa
# Processing Record 46 of Set 5 | olafsvik
# Processing Record 47 of Set 5 | komsomolskiy
# Processing Record 48 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 5 | miraflores
# Processing Record 50 of Set 5 | kajaani
# Processing Record 1 of Set 6 | norwich
# Processing Record 2 of Set 6 | roros
# Processing Record 3 of Set 6 | ashoknagar
# Processing Record 4 of Set 6 | aklavik
# Processing Record 5 of Set 6 | nome
# Processing Record 6 of Set 6 | lazo
# Processing Record 7 of Set 6 | hollins
# Processing Record 8 of Set 6 | qasigiannguit
# Processing Record 9 of Set 6 | asosa
# Processing Record 10 of Set 6 | belmonte
# Processing Record 11 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 6 | vila velha
# Processing Record 15 of Set 6 | pangkalanbuun
# Processing Record 16 of Set 6 | okhotsk
# Processing Record 17 of Set 6 | ulaanbaatar
# Processing Record 18 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 6 | tukrah
# Processing Record 20 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 6 | gari
# Processing Record 22 of Set 6 | namibe
# Processing Record 23 of Set 6 | hirado
# Processing Record 24 of Set 6 | qingquan
# Processing Record 25 of Set 6 | kiruna
# Processing Record 26 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 6 | gat
# Processing Record 28 of Set 6 | laguna
# Processing Record 29 of Set 6 | kadoma
# Processing Record 30 of Set 6 | alausi
# Processing Record 31 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 32 of Set 6 | mount gambier
# Processing Record 33 of Set 6 | andreapol
# Processing Record 34 of Set 6 | inta
# Processing Record 35 of Set 6 | half moon bay
# Processing Record 36 of Set 6 | adrar
# Processing Record 37 of Set 6 | kaeo
# Processing Record 38 of Set 6 | mayo
# Processing Record 39 of Set 6 | kemin
# Processing Record 40 of Set 6 | yasnyy
# Processing Record 41 of Set 6 | mogadishu
# Processing Record 42 of Set 6 | goya
# Processing Record 43 of Set 6 | stabat
# Processing Record 44 of Set 6 | aljezur
# Processing Record 45 of Set 6 | lompoc
# Processing Record 46 of Set 6 | ribeira grande
# Processing Record 47 of Set 6 | ust-omchug
# Processing Record 48 of Set 6 | dong xoai
# Processing Record 49 of Set 6 | varhaug
# Processing Record 50 of Set 6 | bol
# Processing Record 1 of Set 7 | beringovskiy
# Processing Record 2 of Set 7 | rosetta
# Processing Record 3 of Set 7 | belyy yar
# Processing Record 4 of Set 7 | lerwick
# Processing Record 5 of Set 7 | cerrito
# Processing Record 6 of Set 7 | luanda
# Processing Record 7 of Set 7 | cap malheureux
# Processing Record 8 of Set 7 | bowen
# Processing Record 9 of Set 7 | kulhudhuffushi
# Processing Record 10 of Set 7 | coleraine
# Processing Record 11 of Set 7 | akyab
# Processing Record 12 of Set 7 | svetlaya
# Processing Record 13 of Set 7 | nurota
# Processing Record 14 of Set 7 | fort-shevchenko
# Processing Record 15 of Set 7 | neenah
# Processing Record 16 of Set 7 | flin flon
# Processing Record 17 of Set 7 | khatanga
# Processing Record 18 of Set 7 | vredendal
# Processing Record 19 of Set 7 | tynda
# Processing Record 20 of Set 7 | homer
# Processing Record 21 of Set 7 | stornoway
# Processing Record 22 of Set 7 | alofi
# Processing Record 23 of Set 7 | ourossogui
# Processing Record 24 of Set 7 | yambio
# Processing Record 25 of Set 7 | puerto asis
# Processing Record 26 of Set 7 | rio grande
# Processing Record 27 of Set 7 | pandan
# Processing Record 28 of Set 7 | bizhbulyak
# Processing Record 29 of Set 7 | amor
# Processing Record 30 of Set 7 | yar-sale
# Processing Record 31 of Set 7 | zhigansk
# Processing Record 32 of Set 7 | kumano
# Processing Record 33 of Set 7 | san carlos del zulia
# Processing Record 34 of Set 7 | barinas
# Processing Record 35 of Set 7 | arraial do cabo
# Processing Record 36 of Set 7 | vila do maio
# Processing Record 37 of Set 7 | sechelt
# Processing Record 38 of Set 7 | nemuro
# Processing Record 39 of Set 7 | wang saphung
# Processing Record 40 of Set 7 | higuey
# City not found. Skipping...
# Processing Record 41 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 7 | ouesso
# Processing Record 43 of Set 7 | acari
# Processing Record 44 of Set 7 | waitati
# Processing Record 45 of Set 7 | norrkoping
# Processing Record 46 of Set 7 | eganville
# Processing Record 47 of Set 7 | kintinku
# Processing Record 48 of Set 7 | mooi river
# City not found. Skipping...
# Processing Record 49 of Set 7 | mount isa
# Processing Record 50 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 8 | nanpiao
# Processing Record 2 of Set 8 | willowmore
# Processing Record 3 of Set 8 | alakurtti
# Processing Record 4 of Set 8 | dingle
# Processing Record 5 of Set 8 | darasun
# Processing Record 6 of Set 8 | boende
# Processing Record 7 of Set 8 | kharp
# Processing Record 8 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 10 of Set 8 | dauphin
# Processing Record 11 of Set 8 | champerico
# Processing Record 12 of Set 8 | kupang
# Processing Record 13 of Set 8 | pasni
# Processing Record 14 of Set 8 | beaverlodge
# Processing Record 15 of Set 8 | ust-karsk
# Processing Record 16 of Set 8 | smithers
# Processing Record 17 of Set 8 | solnechnyy
# Processing Record 18 of Set 8 | lalomanu
# City not found. Skipping...
# Processing Record 19 of Set 8 | dong hoi
# Processing Record 20 of Set 8 | balkanabat
# Processing Record 21 of Set 8 | cururupu
# Processing Record 22 of Set 8 | puerto quijarro
# Processing Record 23 of Set 8 | vao
# Processing Record 24 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 8 | huangnihe
# Processing Record 26 of Set 8 | chhata
# Processing Record 27 of Set 8 | sur
# Processing Record 28 of Set 8 | birao
# Processing Record 29 of Set 8 | bartica
# Processing Record 30 of Set 8 | vila
# Processing Record 31 of Set 8 | borogontsy
# Processing Record 32 of Set 8 | camacha
# Processing Record 33 of Set 8 | kabalo
# Processing Record 34 of Set 8 | north bend
# Processing Record 35 of Set 8 | moyale
# Processing Record 36 of Set 8 | opuwo
# Processing Record 37 of Set 8 | babushkin
# Processing Record 38 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 39 of Set 8 | macheng
# Processing Record 40 of Set 8 | pevek
# Processing Record 41 of Set 8 | polunochnoye
# Processing Record 42 of Set 8 | turayf
# Processing Record 43 of Set 8 | altay
# Processing Record 44 of Set 8 | varna
# Processing Record 45 of Set 8 | padre bernardo
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | hobyo
# Processing Record 48 of Set 8 | yeppoon
# Processing Record 49 of Set 8 | puerto madero
# Processing Record 50 of Set 8 | atar
# Processing Record 1 of Set 9 | kostomuksha
# Processing Record 2 of Set 9 | brooks
# Processing Record 3 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 4 of Set 9 | flinders
# Processing Record 5 of Set 9 | verkhnyaya inta
# Processing Record 6 of Set 9 | tarakan
# Processing Record 7 of Set 9 | los llanos de aridane
# Processing Record 8 of Set 9 | araouane
# Processing Record 9 of Set 9 | innisfail
# Processing Record 10 of Set 9 | cotonou
# Processing Record 11 of Set 9 | ponta do sol
# Processing Record 12 of Set 9 | port hedland
# Processing Record 13 of Set 9 | hualmay
# Processing Record 14 of Set 9 | columbus
# Processing Record 15 of Set 9 | simao
# Processing Record 16 of Set 9 | ponta delgada
# Processing Record 17 of Set 9 | coihaique
# Processing Record 18 of Set 9 | wanaka
# Processing Record 19 of Set 9 | tahoua
# Processing Record 20 of Set 9 | el dorado
# Processing Record 21 of Set 9 | norsup
# Processing Record 22 of Set 9 | wenling
# Processing Record 23 of Set 9 | marienburg
# Processing Record 24 of Set 9 | paita
# Processing Record 25 of Set 9 | onega
# Processing Record 26 of Set 9 | barra do corda
# Processing Record 27 of Set 9 | tagusao
# Processing Record 28 of Set 9 | buta
# Processing Record 29 of Set 9 | tacuarembo
# Processing Record 30 of Set 9 | margate
# Processing Record 31 of Set 9 | marzuq
# Processing Record 32 of Set 9 | san patricio
# Processing Record 33 of Set 9 | alvaraes
# Processing Record 34 of Set 9 | berlevag
# Processing Record 35 of Set 9 | acapulco
# Processing Record 36 of Set 9 | dudinka
# Processing Record 37 of Set 9 | eyl
# Processing Record 38 of Set 9 | botngard
# Processing Record 39 of Set 9 | eenhana
# Processing Record 40 of Set 9 | katsuura
# Processing Record 41 of Set 9 | yerbogachen
# Processing Record 42 of Set 9 | narsimhapur
# Processing Record 43 of Set 9 | talnakh
# Processing Record 44 of Set 9 | skibbereen
# Processing Record 45 of Set 9 | cartagena
# Processing Record 46 of Set 9 | wad madani
# Processing Record 47 of Set 9 | sayat
# Processing Record 48 of Set 9 | hovd
# Processing Record 49 of Set 9 | fort nelson
# Processing Record 50 of Set 9 | fujin
# Processing Record 1 of Set 10 | urengoy
# Processing Record 2 of Set 10 | katobu
# Processing Record 3 of Set 10 | vawkavysk
# Processing Record 4 of Set 10 | westport
# Processing Record 5 of Set 10 | denpasar
# Processing Record 6 of Set 10 | yulara
# Processing Record 7 of Set 10 | demirci
# Processing Record 8 of Set 10 | kumasi
# Processing Record 9 of Set 10 | santo domingo
# Processing Record 10 of Set 10 | dunedin
# Processing Record 11 of Set 10 | vestmannaeyjar
# Processing Record 12 of Set 10 | la rochelle
# Processing Record 13 of Set 10 | batabano
# Processing Record 14 of Set 10 | the pas
# Processing Record 15 of Set 10 | bunia
# Processing Record 16 of Set 10 | begoro
# Processing Record 17 of Set 10 | vanavara
# Processing Record 18 of Set 10 | anloga
# Processing Record 19 of Set 10 | hasaki
# Processing Record 20 of Set 10 | moanda
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | zavetnoye
# Processing Record 23 of Set 10 | nikel
# Processing Record 24 of Set 10 | sao filipe
# Processing Record 25 of Set 10 | lebu
# Processing Record 26 of Set 10 | chernyshevskiy
# Processing Record 27 of Set 10 | noumea
# Processing Record 28 of Set 10 | nanortalik
# Processing Record 29 of Set 10 | lorengau
# Processing Record 30 of Set 10 | morro bay
# Processing Record 31 of Set 10 | kavieng
# Processing Record 32 of Set 10 | svetlogorsk
# Processing Record 33 of Set 10 | kloulklubed
# Processing Record 34 of Set 10 | cabedelo
# Processing Record 35 of Set 10 | naze
# Processing Record 36 of Set 10 | caravelas
# Processing Record 37 of Set 10 | seymchan
# Processing Record 38 of Set 10 | cape canaveral
# Processing Record 39 of Set 10 | namestovo
# Processing Record 40 of Set 10 | namatanai
# Processing Record 41 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 10 | kimbe
# Processing Record 43 of Set 10 | imeni poliny osipenko
# Processing Record 44 of Set 10 | glenwood springs
# Processing Record 45 of Set 10 | antigonish
# Processing Record 46 of Set 10 | gouyave
# Processing Record 47 of Set 10 | mmathubudukwane
# Processing Record 48 of Set 10 | aykhal
# Processing Record 49 of Set 10 | zaqatala
# Processing Record 50 of Set 10 | inskoy
# Processing Record 1 of Set 11 | merrill
# Processing Record 2 of Set 11 | mandalgovi
# Processing Record 3 of Set 11 | wufeng
# Processing Record 4 of Set 11 | saint-louis
# Processing Record 5 of Set 11 | faya
# Processing Record 6 of Set 11 | kununurra
# Processing Record 7 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 8 of Set 11 | klaebu
# Processing Record 9 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 10 of Set 11 | tilichiki
# Processing Record 11 of Set 11 | miri
# Processing Record 12 of Set 11 | grafton
# Processing Record 13 of Set 11 | huntsville
# Processing Record 14 of Set 11 | dakar
# Processing Record 15 of Set 11 | lavumisa
# Processing Record 16 of Set 11 | klyuchi
# Processing Record 17 of Set 11 | parfenyevo
# Processing Record 18 of Set 11 | batyrevo
# Processing Record 19 of Set 11 | omsukchan
# Processing Record 20 of Set 11 | cuamba
# Processing Record 21 of Set 11 | meadow lake
# Processing Record 22 of Set 11 | ancud
# Processing Record 23 of Set 11 | bayir
# Processing Record 24 of Set 11 | pozo colorado
# Processing Record 25 of Set 11 | dhar
# Processing Record 26 of Set 11 | juazeiro
# Processing Record 27 of Set 11 | sangar
# Processing Record 28 of Set 11 | northam
# Processing Record 29 of Set 11 | nouadhibou
# Processing Record 30 of Set 11 | posse
# Processing Record 31 of Set 11 | nishihara
# Processing Record 32 of Set 11 | alikovo
# Processing Record 33 of Set 11 | sulangan
# Processing Record 34 of Set 11 | tiarei
# Processing Record 35 of Set 11 | sambava
# Processing Record 36 of Set 11 | ringkobing
# Processing Record 37 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 11 | bilma
# Processing Record 39 of Set 11 | sakakah
# Processing Record 40 of Set 11 | teguldet
# Processing Record 41 of Set 11 | yabassi
# Processing Record 42 of Set 11 | kundiawa
# Processing Record 43 of Set 11 | ust-nera
# Processing Record 44 of Set 11 | manacapuru
# Processing Record 45 of Set 11 | leh
# Processing Record 46 of Set 11 | saint-jovite
# Processing Record 47 of Set 11 | san policarpo
# Processing Record 48 of Set 11 | sheltozero
# Processing Record 49 of Set 11 | hearst
# Processing Record 50 of Set 11 | tommot
# Processing Record 1 of Set 12 | assomada
# Processing Record 2 of Set 12 | poronaysk
# Processing Record 3 of Set 12 | boone
# Processing Record 4 of Set 12 | wanlaweyn
# Processing Record 5 of Set 12 | yalova
# Processing Record 6 of Set 12 | quatre cocos
# Processing Record 7 of Set 12 | bolgatanga
# Processing Record 8 of Set 12 | asuncion
# Processing Record 9 of Set 12 | gizo
# Processing Record 10 of Set 12 | antofagasta
# Processing Record 11 of Set 12 | lixourion
# Processing Record 12 of Set 12 | oranjestad
# Processing Record 13 of Set 12 | cao bang
# Processing Record 14 of Set 12 | kibala
# Processing Record 15 of Set 12 | cockburn town
# Processing Record 16 of Set 12 | batemans bay
# Processing Record 17 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 18 of Set 12 | caxito
# Processing Record 19 of Set 12 | mahanoro
# Processing Record 20 of Set 12 | hamilton
# Processing Record 21 of Set 12 | mahibadhoo
# Processing Record 22 of Set 12 | cabungan
# Processing Record 23 of Set 12 | usinsk
# Processing Record 24 of Set 12 | zhanaozen
# Processing Record 25 of Set 12 | llangefni
# Processing Record 26 of Set 12 | veraval
# Processing Record 27 of Set 12 | mineros
# Processing Record 28 of Set 12 | coolum beach
# Processing Record 29 of Set 12 | moindou
# Processing Record 30 of Set 12 | sept-iles
# Processing Record 31 of Set 12 | caborca
# Processing Record 32 of Set 12 | la ronge
# Processing Record 33 of Set 12 | san jeronimo
# Processing Record 34 of Set 12 | bocas del toro
# Processing Record 35 of Set 12 | grants
# Processing Record 36 of Set 12 | sisimiut
# Processing Record 37 of Set 12 | grand gaube
# Processing Record 38 of Set 12 | matadi
# Processing Record 39 of Set 12 | harnoli
# Processing Record 40 of Set 12 | tortoli
# Processing Record 41 of Set 12 | lar
# Processing Record 42 of Set 12 | labuhan
# Processing Record 43 of Set 12 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 44 of Set 12 | padang
# Processing Record 45 of Set 12 | presidencia roque saenz pena
# Processing Record 46 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 12 | vila franca do campo
# Processing Record 48 of Set 12 | belaya gora
# Processing Record 49 of Set 12 | gravelbourg
# Processing Record 50 of Set 12 | ust-tsilma
# Processing Record 1 of Set 13 | salalah
# Processing Record 2 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 13 | kruisfontein
# Processing Record 4 of Set 13 | parit buntar
# Processing Record 5 of Set 13 | ambon
# Processing Record 6 of Set 13 | kuhdasht
# Processing Record 7 of Set 13 | viedma
# Processing Record 8 of Set 13 | roberto payan
# City not found. Skipping...
# Processing Record 9 of Set 13 | taoudenni
# Processing Record 10 of Set 13 | vangaindrano
# Processing Record 11 of Set 13 | rundu
# Processing Record 12 of Set 13 | maxixe
# Processing Record 13 of Set 13 | matay
# Processing Record 14 of Set 13 | rehoboth
# Processing Record 15 of Set 13 | burley
# Processing Record 16 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 13 | tura
# Processing Record 18 of Set 13 | strelka
# Processing Record 19 of Set 13 | buraydah
# Processing Record 20 of Set 13 | raypur
# Processing Record 21 of Set 13 | stepnoye
# Processing Record 22 of Set 13 | beidao
# Processing Record 23 of Set 13 | weihai
# Processing Record 24 of Set 13 | kavaratti
# Processing Record 25 of Set 13 | teya
# Processing Record 26 of Set 13 | yarmouth
# Processing Record 27 of Set 13 | chapais
# Processing Record 28 of Set 13 | samarai
# Processing Record 29 of Set 13 | alice springs
# Processing Record 30 of Set 13 | gamba
# Processing Record 31 of Set 13 | baruun-urt
# Processing Record 32 of Set 13 | vitim
# Processing Record 33 of Set 13 | chicama
# Processing Record 34 of Set 13 | sakaiminato
# Processing Record 35 of Set 13 | biloela
# Processing Record 36 of Set 13 | olga
# Processing Record 37 of Set 13 | bubaque
# Processing Record 38 of Set 13 | mafinga
# Processing Record 39 of Set 13 | ulaangom
# Processing Record 40 of Set 13 | la rioja
# Processing Record 41 of Set 13 | shakawe
# Processing Record 42 of Set 13 | razdolnoye
# Processing Record 43 of Set 13 | gorontalo
# Processing Record 44 of Set 13 | acarau
# Processing Record 45 of Set 13 | almaznyy
# Processing Record 46 of Set 13 | lavrentiya
# Processing Record 47 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 13 | taltal
# Processing Record 49 of Set 13 | antalaha
# Processing Record 50 of Set 13 | avera
# Processing Record 1 of Set 14 | aguada de pasajeros
# Processing Record 2 of Set 14 | huarmey
# Processing Record 3 of Set 14 | satipo
# Processing Record 4 of Set 14 | nelidovo
# Processing Record 5 of Set 14 | biak
# Processing Record 6 of Set 14 | fortuna
# Processing Record 7 of Set 14 | zhangye
# Processing Record 8 of Set 14 | kailua
# Processing Record 9 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 10 of Set 14 | pilar
# Processing Record 11 of Set 14 | mabopane
# Processing Record 12 of Set 14 | taitung
# Processing Record 13 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 14 of Set 14 | port macquarie
# Processing Record 15 of Set 14 | macomb
# Processing Record 16 of Set 14 | portland
# Processing Record 17 of Set 14 | grindavik
# Processing Record 18 of Set 14 | chokwe
# Processing Record 19 of Set 14 | ranghulu
# Processing Record 20 of Set 14 | balabac
# Processing Record 21 of Set 14 | brigantine
# Processing Record 22 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 14 | sitka
# Processing Record 24 of Set 14 | college
# Processing Record 25 of Set 14 | nchelenge
# Processing Record 26 of Set 14 | port shepstone
# Processing Record 27 of Set 14 | yeniseysk
# Processing Record 28 of Set 14 | primorsko
# Processing Record 29 of Set 14 | ixtapa
# Processing Record 30 of Set 14 | maragogi
# Processing Record 31 of Set 14 | tibiri
# Processing Record 32 of Set 14 | luganville
# Processing Record 33 of Set 14 | porto novo
# Processing Record 34 of Set 14 | petrinja
# Processing Record 35 of Set 14 | lakes entrance
# Processing Record 36 of Set 14 | synya
# Processing Record 37 of Set 14 | shingu
# Processing Record 38 of Set 14 | adeje
# Processing Record 39 of Set 14 | banyo
# Processing Record 40 of Set 14 | takoradi
# Processing Record 41 of Set 14 | povenets
# Processing Record 42 of Set 14 | shwebo
# Processing Record 43 of Set 14 | passos
# Processing Record 44 of Set 14 | fredericton
# Processing Record 45 of Set 14 | nioro
# Processing Record 46 of Set 14 | suao
# City not found. Skipping...
# Processing Record 47 of Set 14 | vallenar
# Processing Record 48 of Set 14 | sungaipenuh
# Processing Record 49 of Set 14 | fuzhou
# Processing Record 50 of Set 14 | pudozh
# Processing Record 1 of Set 15 | russellville
# Processing Record 2 of Set 15 | livramento
# Processing Record 3 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 4 of Set 15 | oxford
# Processing Record 5 of Set 15 | katangli
# Processing Record 6 of Set 15 | nakamura
# Processing Record 7 of Set 15 | bolu
# Processing Record 8 of Set 15 | spas-demensk
# Processing Record 9 of Set 15 | changli
# Processing Record 10 of Set 15 | tonj
# Processing Record 11 of Set 15 | cherusti
# Processing Record 12 of Set 15 | abancay
# Processing Record 13 of Set 15 | aporawan
# City not found. Skipping...
# Processing Record 14 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 15 | kalevala
# Processing Record 16 of Set 15 | kembe
# Processing Record 17 of Set 15 | seoul
# Processing Record 18 of Set 15 | shaowu
# Processing Record 19 of Set 15 | launceston
# Processing Record 20 of Set 15 | havelock
# Processing Record 21 of Set 15 | linqiong
# Processing Record 22 of Set 15 | arawa
# Processing Record 23 of Set 15 | matameye
# City not found. Skipping...
# Processing Record 24 of Set 15 | santo angelo
# Processing Record 25 of Set 15 | kachug
# Processing Record 26 of Set 15 | tomatlan
# Processing Record 27 of Set 15 | ekibastuz
# Processing Record 28 of Set 15 | mehamn
# Processing Record 29 of Set 15 | conde
# Processing Record 30 of Set 15 | san jose
# Processing Record 31 of Set 15 | uvira
# Processing Record 32 of Set 15 | bongor
# Processing Record 33 of Set 15 | honningsvag
# Processing Record 34 of Set 15 | kirkuk
# Processing Record 35 of Set 15 | palmer
# Processing Record 36 of Set 15 | makakilo city
# Processing Record 37 of Set 15 | nuevo progreso
# Processing Record 38 of Set 15 | sibolga
# Processing Record 39 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 15 | poum
# Processing Record 41 of Set 15 | inhambane
# Processing Record 42 of Set 15 | soe
# Processing Record 43 of Set 15 | las guacamayas
# Processing Record 44 of Set 15 | kisangani
# Processing Record 45 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 15 | celestun
# Processing Record 47 of Set 15 | novaya igirma
# Processing Record 48 of Set 15 | parrita
# Processing Record 49 of Set 15 | manzhouli
# Processing Record 50 of Set 15 | bahia de caraquez
# Processing Record 1 of Set 16 | manggar
# Processing Record 2 of Set 16 | bandar
# Processing Record 3 of Set 16 | high prairie
# Processing Record 4 of Set 16 | chitral
# Processing Record 5 of Set 16 | ushibuka
# Processing Record 6 of Set 16 | kasongo-lunda
# Processing Record 7 of Set 16 | rabo de peixe
# Processing Record 8 of Set 16 | kudahuvadhoo
# Processing Record 9 of Set 16 | tyazhinskiy
# Processing Record 10 of Set 16 | manta
# Processing Record 11 of Set 16 | sola
# Processing Record 12 of Set 16 | lucapa
# Processing Record 13 of Set 16 | valparaiso
# Processing Record 14 of Set 16 | bijawar
# Processing Record 15 of Set 16 | himora
# City not found. Skipping...
# Processing Record 16 of Set 16 | palafrugell
# Processing Record 17 of Set 16 | pidhaytsi
# Processing Record 18 of Set 16 | shadrinsk
# Processing Record 19 of Set 16 | corning
# Processing Record 20 of Set 16 | san carlos de bariloche
# Processing Record 21 of Set 16 | meulaboh
# Processing Record 22 of Set 16 | aketi
# Processing Record 23 of Set 16 | svetlograd
# Processing Record 24 of Set 16 | bafata
# Processing Record 25 of Set 16 | asyut
# Processing Record 26 of Set 16 | la sarre
# Processing Record 27 of Set 16 | benemerito de las americas
# Processing Record 28 of Set 16 | dickinson
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux      MU -20.34   57.76     73.00        83          75
# 1          Qaanaaq      GL  77.48  -69.36     -1.98        87          99
# 2           Torbay      CA  47.67  -52.73     30.00        58          75
# 3             Ales      FR  44.13    4.08     53.01        56          26
# 4   Saint-Philippe      RE -21.36   55.77     73.40        56          75
# 5      East London      ZA -33.02   27.91     69.80        83          75
# 6           Castro      BR -24.79  -50.01     65.21        69           0
# 7        Saskylakh      RU  71.92  114.08     -3.53        91          97
# 8             Hilo      US  19.73 -155.09     80.60        74          90
# 9      Barkly West      ZA -28.54   24.52     66.20        77         100
#
#    Wind Speed Current Description
# 0        6.93         shower rain
# 1        1.25     overcast clouds
# 2       18.34       broken clouds
# 3        8.01    scattered clouds
# 4       11.41       broken clouds
# 5        5.82       broken clouds
# 6        8.39          light rain
# 7        5.26     overcast clouds
# 8        5.82     overcast clouds
# 9        3.36       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
